# %% [markdown]
# ### Formula
#     ``y=amplitude+sin(2*frequency*time*phi+phase)``

# %%
import numpy as np
import matplotlib.pyplot as plt

amplitude=1
frequency=2 #hz
phi=3.1416

fs=1000 #sampling rate
t=np.arange(1,3,1/fs)
phase=0
y=amplitude+np.sin(2*frequency*t*phi+phase)

plt.plot(t,y)
plt.show()
